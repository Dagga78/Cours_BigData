# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("../data/house_pricing.csv",",",encoding='latin-1', low_memory=False)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
plt.scatter(df['LotArea'], df['SalePrice'])

# %%
df2 = df
df2 = df[df['LotArea']< 20000]
df2 = df[df['SalePrice'] < 500000]
plt.scatter(df2['LotArea'], df2['SalePrice'])

# %%
plt.scatter(df['LotFrontage'], df['LotArea'])

# %%
df3 = df
df3 = df[df['LotArea']< 100000]
df3 = df[df['LotFrontage'] < 200]
plt.scatter(df3['LotFrontage'], df3['LotArea'])

# %%
dfSales = pd.read_csv("../data/sales_predictions.csv",",",encoding='latin-1', low_memory=False)
dfSales
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
g = sns.relplot(x="date", y="item_price", data=dfSales.sample(n=50))

# %%
dfSalessample = dfSales.sample(n=50)
plt.figure(figsize=(20,6))
g = plt.plot(dfSalessample['date'],dfSalessample['item_price'],'.')
plt.xlabel('date')
plt.ylabel('item_price')
# Out:
# Text(0, 0.5, 'item_price')

# %%
dfSales['date'] = pd.to_datetime(dfSales['date'])
dfSales
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0       2013-02-01               0       59    22154      999.00           1.0
# 1       2013-03-01               0       25     2552      899.00           1.0
# 2       2013-05-01               0       25     2552      899.00          -1.0
# 3       2013-06-01               0       25     2554     1709.05           1.0
# 4       2013-01-15               0       25     2555     1099.00           1.0
# ...            ...             ...      ...      ...         ...           ...
# 2935844 2015-10-10              33       25     7409      299.00           1.0
# 2935845 2015-09-10              33       25     7460      299.00           1.0
# 2935846 2015-10-14              33       25     7459      349.00           1.0
# 2935847 2015-10-22              33       25     7440      299.00           1.0
# 2935848 2015-03-10              33       25     7460      299.00           1.0
#
# ...

# %%
dfSalessample = dfSales.sample(n=50)
plt.figure(figsize=(20,6))
g = plt.plot(dfSalessample['date'],dfSalessample['item_price'],'.')
plt.xlabel('date')
plt.ylabel('item_price')
# Out:
# Text(0, 0.5, 'item_price')

# %%
dfibmattrition = pd.read_csv("../data/IBM_HR_ATTRITION.csv",",",encoding='latin-1', low_memory=False)
dfibmattrition.JobSatisfaction.describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sns.catplot(x='Attrition', y='JobSatisfaction', data=dfibmattrition, kind='bar')

# %%
sns.boxplot(x='Attrition', y='JobSatisfaction', data=dfibmattrition)

# %%
dfibmattrition['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sns.boxplot(x='Attrition', y='TotalWorkingYears', data=dfibmattrition)

# %%
dfibmattrition['Attrition'] = dfibmattrition['Attrition'].replace('Yes', 1).replace('No', 0)

# %%
plt.figure(figsize=(20,6))
plt.hist(x=dfibmattrition['EducationField'], bins=10)
# Out:
# (array([606.,   0.,  82.,   0., 464.,   0., 159.,   0., 132.,  27.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(dfibmattrition['MonthlyIncome'],kde=False)

# %%
dfibmattrition = dfibmattrition[dfibmattrition['MonthlyIncome'] <= 5000]
sns.distplot(dfibmattrition['MonthlyIncome'])

# %%
sns.lmplot(x='DistanceFromHome',y='Attrition',data=dfibmattrition)

# %%
sns.lmplot(x="DistanceFromHome", y="YearsWithCurrManager", data=dfibmattrition)

# %%
df = pd.read_csv('../data/resto.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
df.size
# Out:
# 27732

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.groupby(['item_name']).sum().sort_values('quantity', ascending=False)
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %%
df.sum()
# Out:
# Unnamed: 0                                             10679131
# order_id                                                4285772
# quantity                                                   4972
# item_name     Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# item_price    $2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $1...
# dtype: object

# %%
sum = 0

for index, row in df.iterrows():
    row['item_price'] = row['item_price'].replace('$','')
    sum += float(row['item_price']) * float(row['quantity'])

print("Le chiffre d'affaires de Chipotle est de " + str(round(sum,2))  + "$")
    
nb_commande = np.count_nonzero(df.order_id.unique())

avg = sum / nb_commande
print("Le revenu moyen par commande est de " + str(round(avg,2)) + "$")
# Out:
# Le chiffre d'affaires de Chipotle est de 39237.02$
# Le revenu moyen par commande est de 21.39$
